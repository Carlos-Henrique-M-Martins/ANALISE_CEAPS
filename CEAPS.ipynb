# %% [markdown]
# # Importando as bibliotecas e bases de dados

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import plotly.express as px

# %%
# Importando os relatorios da Cota para Exercício da Atividade Parlamentar dos Senadores (CEAPS)

dp_ceaps2022 = pd.read_csv("despesa_ceaps_2022.csv", sep = ';', encoding='unicode_escape', on_bad_lines= 'skip', header=1 )
dp_ceaps2021 = pd.read_csv("despesa_ceaps_2021.csv", sep = ';', encoding='unicode_escape', on_bad_lines= 'skip', header=1 )
dp_ceaps2020 = pd.read_csv("despesa_ceaps_2020.csv", sep = ';', encoding='unicode_escape', on_bad_lines= 'skip', header=1 )
dp_ceaps2019 = pd.read_csv("despesa_ceaps_2019.csv", sep = ';', encoding='latin1', on_bad_lines= 'skip', header=1 )

# %% [markdown]
# # Visualizando e analizando informações gerais da base de dados

# %%
dp_ceaps2019.head(-5)
# Out:
#         ANO  MES        SENADOR  \
# 0      2019    1   ACIR GURGACZ
# 1      2019    1   ACIR GURGACZ
# 2      2019    1   ACIR GURGACZ
# 3      2019    1   ACIR GURGACZ
# 4      2019    2   ACIR GURGACZ
# ...     ...  ...            ...
# 21624  2019    1  ZEZÉ PERRELLA
# 21625  2019    1  ZEZÉ PERRELLA
# 21626  2019    1  ZEZÉ PERRELLA
# 21627  2019    1  ZEZÉ PERRELLA
# 21628  2019    1  ZEZÉ PERRELLA
#
#                                             TIPO_DESPESA            CNPJ_CPF  \
# 0      Aluguel de imóveis para escritório político, c...  05.914.650/0001-66
# 1      Aluguel de imóveis para escritório político, c...  05.914.650/0001-66
# 2      Aluguel de imóveis para escritório político, c...      004.948.028-63
# 3      Aluguel de imóveis para escritório político, c...  05.423.963/0001-11
# 4      Aluguel de imóveis para escritório político, c...  05.914.650/0001-66
# ...                                                  ...                 ...
# ...

# %%
dp_ceaps2020.head(5)
# Out:
#     ANO  MES       SENADOR                                       TIPO_DESPESA  \
# 0  2020    1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 1  2020    1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 2  2020    1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 3  2020    1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 4  2020    1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
#
#              CNPJ_CPF                                         FORNECEDOR  \
# 0  05.914.650/0001-66                                           ENERGISA
# 1  05.914.650/0001-66                                           ENERGISA
# 2      062.135.728-64  FERNANDO WALDEIR PACINI e ANA LUCIA DA SILVA S...
# 3      004.948.028-63                      GILBERTO PISELO DO NASCIMENTO
# 4  05.423.963/0001-11                                      OI MÓVEL S.A.
#
# ...

# %%
dp_ceaps2021.head(5)
# Out:
#     ANO  MES       SENADOR                                       TIPO_DESPESA  \
# 0  2021    1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 1  2021    1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 2  2021    1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 3  2021    1  ACIR GURGACZ                Divulgação da atividade parlamentar
# 4  2021    1  ACIR GURGACZ                Divulgação da atividade parlamentar
#
#              CNPJ_CPF                                         FORNECEDOR  \
# 0  05.914.650/0001-66                                           ENERGISA
# 1      062.135.728-64  FERNANDO WALDEIR PACINI e ANA LUCIA DA SILVA S...
# 2      004.948.028-63                      GILBERTO PISELO DO NASCIMENTO
# 3  26.320.603/0001-64                                      INFORMANAHORA
# 4  13.659.201/0001-47                    LINHA PURPURA FOTO E VIDEO LTDA
#
# ...

# %%
dp_ceaps2022.head(5)
# Out:
#     ANO  MES       SENADOR                                       TIPO_DESPESA  \
# 0  2022    1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 1  2022    1  ACIR GURGACZ                Divulgação da atividade parlamentar
# 2  2022    1  ACIR GURGACZ                Divulgação da atividade parlamentar
# 3  2022    1  ACIR GURGACZ                Divulgação da atividade parlamentar
# 4  2022    1  ACIR GURGACZ                Divulgação da atividade parlamentar
#
#              CNPJ_CPF                                         FORNECEDOR  \
# 0      004.948.028-63                      GILBERTO PISELO DO NASCIMENTO
# 1  26.320.603/0001-64                                      INFORMANAHORA
# 2  13.659.201/0001-47                    LINHA PURPURA FOTO E VIDEO LTDA
# 3  23.652.846/0001-01                  ROBERTO GUTIERREZ DA ROCHA M.E.I.
# 4  08.941.827/0001-01  RONDONIA DINÂMICA COM. E SERV. DE INFORMÁTICA ...
#
#            DOCUMENTO        DATA  \
# ...

# %%
# É importande saber a tipologia dos dados para saber se conferem com a imformaçõão que vai ser tirada eles


print(dp_ceaps2022.info(), dp_ceaps2021.info(), dp_ceaps2020.info(), dp_ceaps2019.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4302 entries, 0 to 4301
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ANO                4302 non-null   int64
#  1   MES                4302 non-null   int64
#  2   SENADOR            4302 non-null   object
#  3   TIPO_DESPESA       4302 non-null   object
#  4   CNPJ_CPF           4302 non-null   object
#  5   FORNECEDOR         4302 non-null   object
#  6   DOCUMENTO          4089 non-null   object
#  7   DATA               4302 non-null   object
#  8   DETALHAMENTO       2200 non-null   object
#  9   VALOR_REEMBOLSADO  4302 non-null   object
#  10  COD_DOCUMENTO      4302 non-null   int64
# dtypes: int64(3), object(8)
# memory usage: 369.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16820 entries, 0 to 16819
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ...

# %%
# Definindo as dimensões das bases de dados

print('O tamanho das bases de dados são:')
print(f' 2019 tem {dp_ceaps2019.shape[0]} linhas e {dp_ceaps2019.shape[1]} colunas.')
print(f' 2020 tem {dp_ceaps2020.shape[0]} linhas e {dp_ceaps2022.shape[1]} colunas.')
print(f' 2021 tem {dp_ceaps2021.shape[0]} linhas e {dp_ceaps2021.shape[1]} colunas.')
print(f' 2022 tem {dp_ceaps2022.shape[0]} linhas e {dp_ceaps2020.shape[1]} colunas.')
# Out:
# O tamanho das bases de dados são:
#  2019 tem 21634 linhas e 11 colunas.
#  2020 tem 14090 linhas e 11 colunas.
#  2021 tem 16820 linhas e 11 colunas.
#  2022 tem 4302 linhas e 11 colunas.

# %% [markdown]
# CONCLUSÃO
#
# os 4 arquivos do CEASP traalhão coms as measmas colunas então não haverá problemas para juntalas em um mesmo Data Frame. Essa ação facilitara o refinamento dos dados e a analise em sí. Foi descoberto que as colunas DATA e VALOR_REEMBOLSADO são do tipo object, sera necessário uma mudança na tipologia deles para que se possar estrair os valores corretos deles.

# %% [markdown]
# # Criando uma base de dados unica

# %%
despesas = pd.concat([dp_ceaps2019, dp_ceaps2020, dp_ceaps2021, dp_ceaps2022])

# %%
despesas.head(-5)
# Out:
#        ANO  MES           SENADOR  \
# 0     2019    1      ACIR GURGACZ
# 1     2019    1      ACIR GURGACZ
# 2     2019    1      ACIR GURGACZ
# 3     2019    1      ACIR GURGACZ
# 4     2019    2      ACIR GURGACZ
# ...    ...  ...               ...
# 4292  2022    4  ZEQUINHA MARINHO
# 4293  2022    4  ZEQUINHA MARINHO
# 4294  2022    4  ZEQUINHA MARINHO
# 4295  2022    4  ZEQUINHA MARINHO
# 4296  2022    4  ZEQUINHA MARINHO
#
#                                            TIPO_DESPESA            CNPJ_CPF  \
# 0     Aluguel de imóveis para escritório político, c...  05.914.650/0001-66
# 1     Aluguel de imóveis para escritório político, c...  05.914.650/0001-66
# 2     Aluguel de imóveis para escritório político, c...      004.948.028-63
# 3     Aluguel de imóveis para escritório político, c...  05.423.963/0001-11
# 4     Aluguel de imóveis para escritório político, c...  05.914.650/0001-66
# ...                                                 ...                 ...
# ...

# %%
# Agora temos apenas uma tabela com todas as informações das anteriores. Isto facilitará e muito as nossas analises 
print(f'Despesas tem {despesas.shape[0]} linhas e {despesas.shape[1]} colunas')
# Out:
# Despesas tem 56846 linhas e 11 colunas

# %% [markdown]
# # Refinando a Base de dados

# %%
#informações do novo DataFrame

despesas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56846 entries, 0 to 4301
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ANO                56846 non-null  int64
#  1   MES                56846 non-null  int64
#  2   SENADOR            56846 non-null  object
#  3   TIPO_DESPESA       56846 non-null  object
#  4   CNPJ_CPF           56846 non-null  object
#  5   FORNECEDOR         56846 non-null  object
#  6   DOCUMENTO          54604 non-null  object
#  7   DATA               56846 non-null  object
#  8   DETALHAMENTO       31714 non-null  object
#  9   VALOR_REEMBOLSADO  56846 non-null  object
#  10  COD_DOCUMENTO      56846 non-null  int64
# dtypes: int64(3), object(8)
# memory usage: 5.2+ MB

# %%
#Verificando se existe valores nulos

despesas.isnull().sum()
# Out:
# ANO                      0
# MES                      0
# SENADOR                  0
# TIPO_DESPESA             0
# CNPJ_CPF                 0
# FORNECEDOR               0
# DOCUMENTO             2242
# DATA                     0
# DETALHAMENTO         25132
# VALOR_REEMBOLSADO        0
# COD_DOCUMENTO            0
# dtype: int64

# %%
#Transformando valores nulos em 0

despesas['DOCUMENTO'].fillna(value= 0, inplace = True)

# Pelo fato da coluna de  detalhamento poder conter informações relevantes foi optado em criar o termo de não informado
despesas['DETALHAMENTO'].fillna(value = 'Não informado', inplace = True)

# %%
# verificando se não existe mais valores nulos 

despesas.isnull().sum()
# Out:
# ANO                  0
# MES                  0
# SENADOR              0
# TIPO_DESPESA         0
# CNPJ_CPF             0
# FORNECEDOR           0
# DOCUMENTO            0
# DATA                 0
# DETALHAMENTO         0
# VALOR_REEMBOLSADO    0
# COD_DOCUMENTO        0
# dtype: int64

# %%
# Eliminando colunas com informações não relacionadas a pesquisa

despesas = despesas.drop(columns = ['CNPJ_CPF', 'DOCUMENTO', 'COD_DOCUMENTO'])

# %%
despesas
# Out:
#        ANO  MES           SENADOR  \
# 0     2019    1      ACIR GURGACZ
# 1     2019    1      ACIR GURGACZ
# 2     2019    1      ACIR GURGACZ
# 3     2019    1      ACIR GURGACZ
# 4     2019    2      ACIR GURGACZ
# ...    ...  ...               ...
# 4297  2022    4  ZEQUINHA MARINHO
# 4298  2022    4  ZEQUINHA MARINHO
# 4299  2022    4  ZEQUINHA MARINHO
# 4300  2022    4  ZEQUINHA MARINHO
# 4301  2022    4  ZEQUINHA MARINHO
#
#                                            TIPO_DESPESA  \
# 0     Aluguel de imóveis para escritório político, c...
# 1     Aluguel de imóveis para escritório político, c...
# 2     Aluguel de imóveis para escritório político, c...
# 3     Aluguel de imóveis para escritório político, c...
# 4     Aluguel de imóveis para escritório político, c...
# ...                                                 ...
# 4297  Passagens aéreas, aquáticas e terrestres nacio...
# 4298  Passagens aéreas, aquáticas e terrestres nacio...
# ...

# %%
# É precisoo transformar a data em uma datetime mais existe algumas linhas dando erro então será necessário uma limpesa

despesas['NOVA_DATA'] = pd.to_datetime(despesas['DATA'], format="%d/%m/%Y", errors='coerce')

# %%
despesas.query("NOVA_DATA == 'NaN'")
# Out:
#         ANO  MES         SENADOR  \
# 10986  2019    1     LÚCIA VÂNIA
# 10362  2020    5  PLÍNIO VALÉRIO
# 2147   2021   11    CARLOS VIANA
#
#                                             TIPO_DESPESA  \
# 10986  Aluguel de imóveis para escritório político, c...
# 10362                Divulgação da atividade parlamentar
# 2147   Passagens aéreas, aquáticas e terrestres nacio...
#
#                                               FORNECEDOR        DATA  \
# 10986  LDE Contabilidade e Administração de Condomíni...  31/01/0219
# 10362                 Excelsior Comunicação Digital Ltda  05/05/0202
# 2147                        ADRIA VIAGENS E TURISMO LTDA  29/10/0202
#
#                                             DETALHAMENTO VALOR_REEMBOLSADO  \
# 10986                                   Taxa condominial            271,26
# 10362                                      Não informado              1150
# 2147   Companhia Aérea: AZUL, Localizador: YK1QHD. Pa...             339,9
#
# ...

# %%
despesas['DATA'] = despesas['DATA'].replace('31/01/0219','31/01/2019')
despesas['DATA'] = despesas['DATA'].replace('05/05/0202','05/05/2020')
despesas['DATA'] = despesas['DATA'].replace('29/10/0202','29/10/2020')

# %%
despesas['DATA'] = pd.to_datetime(despesas['DATA'], format="%d/%m/%Y")

# %%
despesas = despesas.drop(columns = 'NOVA_DATA')

# %%
# A transformação da coluna data foi bem sucedida

despesas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56846 entries, 0 to 4301
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ANO                56846 non-null  int64
#  1   MES                56846 non-null  int64
#  2   SENADOR            56846 non-null  object
#  3   TIPO_DESPESA       56846 non-null  object
#  4   FORNECEDOR         56846 non-null  object
#  5   DATA               56846 non-null  datetime64[ns]
#  6   DETALHAMENTO       56846 non-null  object
#  7   VALOR_REEMBOLSADO  56846 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(5)
# memory usage: 3.9+ MB

# %%
# transformando ',' da coluna VALOR_REEMBOLSADO em '.' para tornala em float

despesas['VALOR_REEMBOLSADO'] = despesas['VALOR_REEMBOLSADO'].replace(',', '.', regex= True)

# Tranformando a coluna em float

despesas['VALOR_REEMBOLSADO'] = despesas['VALOR_REEMBOLSADO'].astype(float)

# %%
# Mudando a nomenclatura da coluna tipo_despesa

despesas['TIPO_DESPESA'].unique()
# Out:
# array(['Aluguel de imóveis para escritório político, compreendendo despesas concernentes a eles.',
#        'Divulgação da atividade parlamentar',
#        'Aquisição de material de consumo para uso no escritório político, inclusive aquisição ou locação de software, despesas postais, aquisição de publicações, locação de móveis e de equipamentos. ',
#        'Passagens aéreas, aquáticas e terrestres nacionais',
#        'Contratação de consultorias, assessorias, pesquisas, trabalhos técnicos e outros serviços de apoio ao exercício do mandato parlamentar',
#        'Locomoção, hospedagem, alimentação, combustíveis e lubrificantes',
#        'Serviços de Segurança Privada'], dtype=object)

# %%
tipos_de_gastos = {'Aluguel de imóveis para escritório político, compreendendo despesas concernentes a eles.' : 'Aluguel de imoveis',
       'Divulgação da atividade parlamentar' : 'Divulgação da atividade parlamentar',
       'Aquisição de material de consumo para uso no escritório político, inclusive aquisição ou locação de software, despesas postais, aquisição de publicações, locação de móveis e de equipamentos. ' : 'Aquisição de Materiais gerais',
       'Passagens aéreas, aquáticas e terrestres nacionais' : 'Transporte',
       'Contratação de consultorias, assessorias, pesquisas, trabalhos técnicos e outros serviços de apoio ao exercício do mandato parlamentar' : 'Contratações',
       'Locomoção, hospedagem, alimentação, combustíveis e lubrificantes' : 'Verba de viagem',
       'Serviços de Segurança Privada' : 'Serviços de Segurança Privada'}

# %%
despesas['TIPO_DESPESA'] = despesas['TIPO_DESPESA'].map(tipos_de_gastos)

# %%
# Base de dados filtrada
despesas
# Out:
#        ANO  MES           SENADOR        TIPO_DESPESA  \
# 0     2019    1      ACIR GURGACZ  Aluguel de imoveis
# 1     2019    1      ACIR GURGACZ  Aluguel de imoveis
# 2     2019    1      ACIR GURGACZ  Aluguel de imoveis
# 3     2019    1      ACIR GURGACZ  Aluguel de imoveis
# 4     2019    2      ACIR GURGACZ  Aluguel de imoveis
# ...    ...  ...               ...                 ...
# 4297  2022    4  ZEQUINHA MARINHO          Transporte
# 4298  2022    4  ZEQUINHA MARINHO          Transporte
# 4299  2022    4  ZEQUINHA MARINHO          Transporte
# 4300  2022    4  ZEQUINHA MARINHO          Transporte
# 4301  2022    4  ZEQUINHA MARINHO          Transporte
#
#                          FORNECEDOR       DATA  \
# 0                          ENERGISA 2019-01-04
# 1                          ENERGISA 2019-01-04
# 2     GILBERTO PISELO DO NASCIMENTO 2019-01-07
# 3                     OI MÓVEL S.A. 2018-12-25
# 4                          ENERGISA 2019-02-04
# ...

# %% [markdown]
# CONCLUSÃO
#
# Todass as alterações na tipologia dos dados, formatação do conteudo e exclusão de fatores não determinantes da pesquisa foi bem sucedida.

# %% [markdown]
# # Analise da base de dados

# %% [markdown]
# ## Qual é o periodo do ano em que mais ocorrre gastos publicos?

# %%
# Visualisando o total de gastos por mes

ax = despesas.groupby('MES')['VALOR_REEMBOLSADO'].sum().reset_index()
fig = px.bar(ax, x='MES',y='VALOR_REEMBOLSADO', 
             title="Gastos por mes",
             text_auto='.2s'
            )
fig.update_traces(textfont_size=12, textangle=0, textposition="outside")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Visualizando s gastos em um ano eleitoral
ax1 = despesas.query("ANO == 2019")
ax = ax1.groupby('MES')['VALOR_REEMBOLSADO'].sum().reset_index()
fig = px.bar(ax, x='MES',y='VALOR_REEMBOLSADO', 
             title="Gastos por mes No ano de 2019", text_auto= '.2s'
            )
fig.update_traces(textfont_size=12, textangle=0, textposition="outside")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# CONCLUSÃO
#
# O primeiro grafico afirma que os gastos dos senadores cresce consideravelmente entre o fim e o inicio do ano(Desembro a março), sendo este o periodo que há mais gastos por parte dos Senadores. Contudo o segundo grafico mostra que em um ano eleitoral os gastos se concentrão em no meio para o final do ano muito provavelmente devido aos conpromissos de campanha.

# %% [markdown]
# ## Qual a media de reenbousos feitos pelos senadores?

# %%
# o numero do reembolso

despesas['VALOR_REEMBOLSADO'].sum()
# Out:
# 77646339.45

# %%
# E necessário criar uma media anual com o valor de reembolso com o numero de cadeiras do Senado (81) nos 4 anos analisados. 

media = (despesas['VALOR_REEMBOLSADO'].sum() / 81) / 4
media
# Out:
# 239649.19583333333

# %%
print(f'A media geral de reembouso anual de cada senador nesses ultimos 4 anos foi de R$ {media.round(2)}')
# Out:
# A media geral de reembouso anual dos senadores nesses ultimos 4 anos foi de R$ 239649.2

# %% [markdown]
# CONCLUSÃO
#
# Com a base de dados do CEAPS foi possivel definir que o reembolso medio de cada senador pede é de R$ 239.649,20 por ano.

# %% [markdown]
# ## Qual e o gasto mais comum entre os senadores?

# %%
gastos = despesas.groupby(['TIPO_DESPESA']).VALOR_REEMBOLSADO.sum()
gastos
# Out:
# TIPO_DESPESA
# Aluguel de imoveis                     13261307.01
# Aquisição de Materiais gerais           3080094.09
# Contratações                           19734142.91
# Divulgação da atividade parlamentar    10683758.62
# Serviços de Segurança Privada            127540.44
# Transporte                             17007619.84
# Verba de viagem                        13751876.54
# Name: VALOR_REEMBOLSADO, dtype: float64

# %%
tipos_gastos = gastos.sort_values(ascending=False)
tipos_gastos
# Out:
# TIPO_DESPESA
# Contratações                           19734142.91
# Transporte                             17007619.84
# Verba de viagem                        13751876.54
# Aluguel de imoveis                     13261307.01
# Divulgação da atividade parlamentar    10683758.62
# Aquisição de Materiais gerais           3080094.09
# Serviços de Segurança Privada            127540.44
# Name: VALOR_REEMBOLSADO, dtype: float64

# %%
tipos_gastos = pd.DataFrame(tipos_gastos)   
tipos_gastos
# Out:
#                                      VALOR_REEMBOLSADO
# TIPO_DESPESA
# Contratações                               19734142.91
# Transporte                                 17007619.84
# Verba de viagem                            13751876.54
# Aluguel de imoveis                         13261307.01
# Divulgação da atividade parlamentar        10683758.62
# Aquisição de Materiais gerais               3080094.09
# Serviços de Segurança Privada                127540.44

# %%
tipos_gastos['VALOR_REEMBOLSADO'].sum()
# Out:
# 77646339.45

# %% [markdown]
# CONCLUSÃO
#
# O maiores gastos por parte dos senadores são na contratação de pessoal, uso de transporte e na verba de viagem.

# %% [markdown]
# quais os 5 principais fornecedores por categoria de gastos?
#
# qual foi o senador com maiores gastos neste periodo?

# %%
senadores = despesas.groupby(['SENADOR']).VALOR_REEMBOLSADO.sum()
senadores = senadores.sort_values(ascending=False)
senadores = pd.DataFrame(senadores)
senadores
# Out:
#                       VALOR_REEMBOLSADO
# SENADOR
# ROGÉRIO CARVALHO             1594573.55
# TELMÁRIO MOTA                1590603.79
# PAULO ROCHA                  1556141.47
# MECIAS DE JESUS              1504720.88
# MAILZA GOMES                 1476292.32
# ...                                 ...
# SIQUEIRA CAMPOS                 5926.99
# VIRGINIO DE CARVALHO            5720.56
# MAGNO MALTA                     4725.79
# JOSÉ PIMENTEL                   4713.74
# NAILDE PANTA                    1650.62
#
# [140 rows x 1 columns]

# %%
#para Melhorar a visualização foi escolhido criar uma base com apenas os 5 primeiros Senadores

top_senadores = senadores.head(5)
top_senadores
# Out:
#                   VALOR_REEMBOLSADO
# SENADOR
# ROGÉRIO CARVALHO         1594573.55
# TELMÁRIO MOTA            1590603.79
# PAULO ROCHA              1556141.47
# MECIAS DE JESUS          1504720.88
# MAILZA GOMES             1476292.32

# %% [markdown]
# CONCLUSÃO
#
# O Senador que mais reembolsou dinheiro público de acordo com a base de dados da CEAPS nos ultimos 4 anos foi o senador Rogerio Carvalho
